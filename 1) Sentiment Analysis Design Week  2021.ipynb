# %% [markdown]
# # Twitter Sentiment Analysis

# %% [markdown]
# #### INTRODUZIONE:
#
# A che cosa serve?: <br>
# il progetto è creare un programma che possa prevedere uno o più trends di mercato tramite l'analisi di sentimento  <br>
# su una o più keyword fornite da un utente. I dati sono la chiave del futuro successo di un'azienda, la combinazione  <br>
# di dati estratti dal web (questo programma) con dati provenienti dai database interni creerà una visione sempre più <br>
# nitida delle scelte da per il managment, aiutando a prendere decisioni future sulla base di solidi dati. <br>
# <br>
# Perche?: <br>
# il programma analizza i tweets delle persone per delineare un trend di mercato, è stato eseguito pochi giorni prima <br>
# della Design Week del 2021, si è voluto utilizzare come input per il programma le parole generiche di: moda milano <br> circoscrivendo la ricerca in Italia e ad un massimo di 502 tweet da analizzare (non ci sono limiti al numero) <br>
# <br>
# Come?: <br>
# Il progetto è svolto tramite interrogazione di API del social Twitter con linguaggio Python. <br>

# %%
# dopo aver estratto i nostri tweet li dividiamo in due categorie: Positivi e Negativi
# Out:
# positive    477
# negative     24
# Name: sentiment, dtype: int64

# %%
# Entrando più in profondità possiamo dedurre i sentimenti dei tweet
# Out:
# joy        475
# anger       12
# sadness     10
# fear         4
# Name: emotion, dtype: int64

# %%
# Nei molteplici Tweet estratti vogliamo sapere il parerei solo degli Influencer, creando un Polarity Chart per esservare ogni tweet e il suo peso in termini di negativià o positività,
# avendo in secondo luogo la possibilità di risalire ad ogni tweets. Non vengono riportati per lunghezza ma è possibile risalire al testo e link di ogni tweet estratto
# Out:
# The result of the influencers theme gave result positive: 12.55
# the count of tweets positive and negative is: Positive: {59} Negative: {34}

# %%
# Chiediamo di estrarre tramite un grafico Wordcloud solo le parole più utilizzate,
# vi è la possiblità di affinare la ricerca escludendo parole, entrando sempre più nel dettaglio delle parole più usate

# %%
# Word frequency
# Out:
# [('design', 465), ('milano', 455), ('week', 226), ('2021', 79), ('settembre', 34), ('salone', 32), ('honda', 32), ('museo', 30), ('nuova', 28)]

# %%
# qua vediamo le parole con il peso maggiore per le keywords di moda e milano
# Out:
# Trigramma, sottosequenza di 3 elementi di una data sequenza e peso che hanno nei testi
# [('milano design week', 177),
#  ('alla milano design', 77),
#  ('design week 2021', 39),
#  ('design group tutta', 25),
#  ('group tutta convenzionalita', 25),
#  ('tutta convenzionalita alla', 25),
#  ('convenzionalita alla milano', 25),
#  ('milano museo design', 21),
#  ('della milano design', 20),
#  ('durante milano design', 15),
#  ('salone mobile milano', 15),
#  ('design week milano', 15),
#  ('honda full hybrid', 12),
#  ('marazzato alla milano', 11),
#  ('rifiuti ambiente successo', 10),
#  ('ambiente successo marazzato', 10),
#  ('successo marazzato alla', 10),
#  ('alla design week', 9),
#  ('giovedi venerdi settembre', 9),
#  ('fuori salone mobile', 9)]

# %%
# questo è un grafico che delinea un trend per 3 mesi passato, attuale e futuro, partendo da Luglio 2021 per le parole Moda e Milano fino ad ottobre 
# Si utilizza guardando i picchi di interesse si estrare il periodo di riferimento settimanalmente e si analizzano i tweet del periodo per delineare un 
# trend che possa influenzare e veicolare i tweet attuali e futuri.
# Out:
# Wall time: 34.7 s
