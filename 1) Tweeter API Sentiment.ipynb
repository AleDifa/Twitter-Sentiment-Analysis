# %% [markdown]
# # Twitter Sentiment Analysis

# %%
### Import Libraries
# cleaning and manipulation text
import pandas as pd
import matplotlib.pyplot as plt
import re
from translate import Translator
import datetime
import unidecode

# Twitter
#import tweepy
import snscrape.modules.twitter

# NLP - Sentiment analysis libraries
from textblob import TextBlob  
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from rake_nltk import Rake
from nltk.util import ngrams


#import collections
from collections import Counter
from wordcloud import WordCloud, STOPWORDS
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from sklearn.feature_extraction.text import CountVectorizer

# for italian sentiment and emotions
from transformers import pipeline
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer 
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-it-en")
tokenizer = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-it-en") 


#pip install feel-it
from feel_it import EmotionClassifier, SentimentClassifier 

import warnings
warnings.filterwarnings('ignore')

# %%
# Out:
# positive    477
# negative     24
# Name: sentiment, dtype: int64

# %%
# Out:
# joy        475
# anger       12
# sadness     10
# fear         4
# Name: emotion, dtype: int64

# %%
# influencer analysis
# Out:
# The result of the influencers theme gave result positive: 12.55
# the count of tweets positive and negative is: Positive: {59} Negative: {34}

# %%
# tweet positivi
# Out:
# <style type="text/css">
# </style>
# <table id="T_977cf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >tweet.text</th>
#       <th class="col_heading level0 col1" >tweet.user.username</th>
#       <th class="col_heading level0 col2" >tweet.url</th>
#       <th class="col_heading level0 col3" >emotion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_977cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_977cf_row0_col0" class="data row0 col0" >ospitiamo mostre d'arte e fotografia, showroom di design e moda. siamo a milano, in sant'ambrogio. se vuoi esporre, contattaci https://t.co/oq5i6c86fg https://t.co/wv8tptxev3</td>
#       <td id="T_977cf_row0_col1" class="data row0 col1" >IDEA4MI</td>
#       <td id="T_977cf_row0_col2" class="data row0 col2" ><a href="https://twitter.com/IDEA4MI/status/1448004794216587269">https://twitter.com/IDEA4MI/status/1448004794216587269</a></td>
#       <td id="T_977cf_row0_col3" class="data row0 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_977cf_row1_col0" class="data row1 col0" >@acmilan  'architettura di milano' https://t.co/soonn2nfny</td>
#       <td id="T_977cf_row1_col1" class="data row1 col1" >dlszdesign</td>
#       <td id="T_977cf_row1_col2" class="data row1 col2" ><a href="https://twitter.com/dlszdesign/status/1447954307798732802">https://twitter.com/dlszdesign/status/1447954307798732802</a></td>
#       <td id="T_977cf_row1_col3" class="data row1 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_977cf_row2_col0" class="data row2 col0" >marco de silvestri, smo at #radicigroup, al corso fashion design organizzato dalla scuola del design del mip politecnico di milano, ha presentato agli studenti i prodotti riciclati e riciclabili del gruppo, sottolineando l'importanza della progettazione in #ecodesign. https://t.co/29tjnfokyu</td>
#       <td id="T_977cf_row2_col1" class="data row2 col1" >RadiciGroup</td>
#       <td id="T_977cf_row2_col2" class="data row2 col2" ><a href="https://twitter.com/RadiciGroup/status/1447919059127914511">https://twitter.com/RadiciGroup/status/1447919059127914511</a></td>
#       <td id="T_977cf_row2_col3" class="data row2 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_977cf_row3_col0" class="data row3 col0" >milano design film festival - 9a edizione di reset dal 21 al 24 ottobre https://t.co/bwmf2ehwtm</td>
#       <td id="T_977cf_row3_col1" class="data row3 col1" >milanmagazine_</td>
#       <td id="T_977cf_row3_col2" class="data row3 col2" ><a href="https://twitter.com/milanmagazine_/status/1447910940712730628">https://twitter.com/milanmagazine_/status/1447910940712730628</a></td>
#       <td id="T_977cf_row3_col3" class="data row3 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_977cf_row4_col0" class="data row4 col0" >milano design film festival - 9a edizione di reset dal 21 al 24 ottobre https://t.co/ok3lolsgh1</td>
#       <td id="T_977cf_row4_col1" class="data row4 col1" >apetrazzuolo</td>
#       <td id="T_977cf_row4_col2" class="data row4 col2" ><a href="https://twitter.com/apetrazzuolo/status/1447910188111912975">https://twitter.com/apetrazzuolo/status/1447910188111912975</a></td>
#       <td id="T_977cf_row4_col3" class="data row4 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_977cf_row5_col0" class="data row5 col0" >milano design film festival - 9a edizione di reset dal 21 al 24 ottobre https://t.co/vplnw2tipv</td>
#       <td id="T_977cf_row5_col1" class="data row5 col1" >napolimagazine</td>
#       <td id="T_977cf_row5_col2" class="data row5 col2" ><a href="https://twitter.com/napolimagazine/status/1447910183447896069">https://twitter.com/napolimagazine/status/1447910183447896069</a></td>
#       <td id="T_977cf_row5_col3" class="data row5 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_977cf_row6_col0" class="data row6 col0" >presentata la 9. ed. di #milanodesignfilmfestival: 50 titoli tra documentari,  inchieste, fiction e film per avvicinare il grande pubblico  alle concezioni piu contemporanee del #design e dell' #architettura. dal 21 al 24 ottobre. #mdff #culturamilano https://t.co/4hkzkxwptr https://t.co/68sn2tywnn</td>
#       <td id="T_977cf_row6_col1" class="data row6 col1" >culturamilano</td>
#       <td id="T_977cf_row6_col2" class="data row6 col2" ><a href="https://twitter.com/culturamilano/status/1447896157498363907">https://twitter.com/culturamilano/status/1447896157498363907</a></td>
#       <td id="T_977cf_row6_col3" class="data row6 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_977cf_row7_col0" class="data row7 col0" >milano universita degli studi di milano - cortile d'onore
# high intensity design training - fare allenamento con il proprio passato, naba
# #interni
# #naba #claudiolarcher #sararicciardi
# #fuorisalone #mdw2021
# #1blog4u #gabriellaruggieri
# ph #vaifrominoretti
# https://t.co/ohi4kv2i9q https://t.co/dnkv38wikz</td>
#       <td id="T_977cf_row7_col1" class="data row7 col1" >1Blog4u</td>
#       <td id="T_977cf_row7_col2" class="data row7 col2" ><a href="https://twitter.com/1Blog4u/status/1447598084666572808">https://twitter.com/1Blog4u/status/1447598084666572808</a></td>
#       <td id="T_977cf_row7_col3" class="data row7 col3" >sadness</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_977cf_row8_col0" class="data row8 col0" >gite fuori porta? ecco una bella idea e voi dove andreste per una giornata fuori milano?
# #inlombardia #milano @inlombardia #turismo #turismodiprossimita #tourism https://t.co/tvhh1kt5ll</td>
#       <td id="T_977cf_row8_col1" class="data row8 col1" >5vieartdesign</td>
#       <td id="T_977cf_row8_col2" class="data row8 col2" ><a href="https://twitter.com/5vieartdesign/status/1447597345454108678">https://twitter.com/5vieartdesign/status/1447597345454108678</a></td>
#       <td id="T_977cf_row8_col3" class="data row8 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_977cf_row9_col0" class="data row9 col0" >ospitiamo mostre d'arte e fotografia, showroom di design e moda. siamo a milano, in sant'ambrogio. se vuoi esporre, contattaci https://t.co/oq5i6bqur6 https://t.co/5a1fl3mrs2</td>
#       <td id="T_977cf_row9_col1" class="data row9 col1" >IDEA4MI</td>
#       <td id="T_977cf_row9_col2" class="data row9 col2" ><a href="https://twitter.com/IDEA4MI/status/1447581505241321477">https://twitter.com/IDEA4MI/status/1447581505241321477</a></td>
#       <td id="T_977cf_row9_col3" class="data row9 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_977cf_row10_col0" class="data row10 col0" >#formazione interior design: alla ricerca di spazi flessibili, innovazioni sostenibili e nuove cromie - la fondazione ordine architetti di milano organizza un corso di formazione online per architetti incentrato sul https://t.co/0zyv5rd2pv</td>
#       <td id="T_977cf_row10_col1" class="data row10 col1" >profarchitetto</td>
#       <td id="T_977cf_row10_col2" class="data row10 col2" ><a href="https://twitter.com/profarchitetto/status/1447566742067335176">https://twitter.com/profarchitetto/status/1447566742067335176</a></td>
#       <td id="T_977cf_row10_col3" class="data row10 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_977cf_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_977cf_row11_col0" class="data row11 col0" >#onebarangaroo: il miglior #grattaciel

# %%
# tweet negativi
# Out:
# <style type="text/css">
# </style>
# <table id="T_3fc02_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >tweet.text</th>
#       <th class="col_heading level0 col1" >tweet.user.username</th>
#       <th class="col_heading level0 col2" >tweet.url</th>
#       <th class="col_heading level0 col3" >emotion</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fc02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3fc02_row0_col0" class="data row0 col0" >a cosa serve la manifattura digitale a una citta come milano? https://t.co/nyjjs3cwcd</td>
#       <td id="T_3fc02_row0_col1" class="data row0 col1" >passionedesign</td>
#       <td id="T_3fc02_row0_col2" class="data row0 col2" ><a href="https://twitter.com/passionedesign/status/1445817731429945345">https://twitter.com/passionedesign/status/1445817731429945345</a></td>
#       <td id="T_3fc02_row0_col3" class="data row0 col3" >anger</td>
#     </tr>
#     <tr>
#       <th id="T_3fc02_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3fc02_row1_col0" class="data row1 col0" >@faberskj in quella stanza ci starebbe bene qualche soprammobile di design,tanto x far capire che sei di milano e non di cazzago brabbia,onno o andrate:un figo di milano!</td>
#       <td id="T_3fc02_row1_col1" class="data row1 col1" >f4t_ale</td>
#       <td id="T_3fc02_row1_col2" class="data row1 col2" ><a href="https://twitter.com/f4t_ale/status/1443971388319141889">https://twitter.com/f4t_ale/status/1443971388319141889</a></td>
#       <td id="T_3fc02_row1_col3" class="data row1 col3" >anger</td>
#     </tr>
#     <tr>
#       <th id="T_3fc02_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3fc02_row2_col0" class="data row2 col0" >la milano europea.
# la citta del futuro.
# la capitale del design.
# il place to be.
# ultimamente quaggiu abbiamo un serio problema con la spazzatura e la pulizia delle strade. ve ne siete accorti?
# viale romagna/piazzale susa
# @amsa_spa
# @comunemi
# @corrieremilano
# @rep_milano https://t.co/qvoyftz02a</td>
#       <td id="T_3fc02_row2_col1" class="data row2 col1" >RobertoChiarell</td>
#       <td id="T_3fc02_row2_col2" class="data row2 col2" ><a href="https://twitter.com/RobertoChiarell/status/1443840674567237658">https://twitter.com/RobertoChiarell/status/1443840674567237658</a></td>
#       <td id="T_3fc02_row2_col3" class="data row2 col3" >anger</td>
#     </tr>
#     <tr>
#       <th id="T_3fc02_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3fc02_row3_col0" class="data row3 col0" >@_schiaffino__ @haugefan stile ripetitivo (vedi allianz arena). si e propeso per un design innovativo e distintivo dei simboli di milano. d'altronde il focus e renderlo non replicabile.</td>
#       <td id="T_3fc02_row3_col1" class="data row3 col1" >SergioSpdvcha</td>
#       <td id="T_3fc02_row3_col2" class="data row3 col2" ><a href="https://twitter.com/SergioSpdvcha/status/1443498432061128708">https://twitter.com/SergioSpdvcha/status/1443498432061128708</a></td>
#       <td id="T_3fc02_row3_col3" class="data row3 col3" >sadness</td>
#     </tr>
#     <tr>
#       <th id="T_3fc02_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3fc02_row4_col0" class="data row4 col0" >#robee, il primo #robot #umanoide #madeinitaly che affianca le persone nei lavori pericolosi. creato dall'azienda #oversonic, per la quale abbiamo organizzato la presentazione del robot alla stampa a milano, presso adi design museum
# leggi il comunicato  https://t.co/2dgiklzr5q https://t.co/fprvplfkj1</td>
#       <td id="T_3fc02_row4_col1" class="data row4 col1" >twin_services</td>
#       <td id="T_3fc02_row4_col2" class="data row4 col2" ><a href="https://twitter.com/twin_services/status/1443495444307456001">https://twitter.com/twin_services/status/1443495444307456001</a></td>
#       <td id="T_3fc02_row4_col3" class="data row4 col3" >fear</td>
#     </tr>
#     <tr>
#       <th id="T_3fc02_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3fc02_row5_col0" class="data row5 col0" >@atletico_design il gol della milano di serie b peraltro era da annullare perche c'era romagnoli in fuorigioco sulla traiettoria di oblak...</td>
#       <td id="T_3fc02_row5_col1" class="data row5 col1" >Lazpao75Paolo</td>
#       <td id="T_3fc02_row5_col2" class="data row5 col2" ><a href="https://twitter.com/Lazpao75Paolo/status/1443439234392678410">https://twitter.com/Lazpao75Paolo/status/1443439234392678410</a></td>
#       <td id="T_3fc02_row5_col3" class="data row5 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_3fc02_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3fc02_row6_col0" class="data row6 col0" >tra venti giorni inizia l'universita e dovrei trasferirmi a milano a studiare design??? da sola??? che ansiaaa
#
# qualche moots studia/studiera a milano?</td>
#       <td id="T_3fc02_row6_col1" class="data row6 col1" >BUCK_13x</td>
#       <td id="T_3fc02_row6_col2" class="data row6 col2" ><a href="https://twitter.com/BUCK_13x/status/1443135139765276677">https://twitter.com/BUCK_13x/status/1443135139765276677</a></td>
#       <td id="T_3fc02_row6_col3" class="data row6 col3" >fear</td>
#     </tr>
#     <tr>
#       <th id="T_3fc02_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3fc02_row7_col0" class="data row7 col0" >la milano europea.
# la citta del futuro.
# la capitale del design.
# il place to be.
# ultimamente quaggiu abbiamo un serio problema con la spazzatura e la pulizia delle strade. ve ne siete accorti?
# @amsa_spa
# @comunemi
# @corrieremilano
# @rep_milano https://t.co/ek28zcaq95</td>
#       <td id="T_3fc02_row7_col1" class="data row7 col1" >lcasillo</td>
#       <td id="T_3fc02_row7_col2" class="data row7 col2" ><a href="https://twitter.com/lcasillo/status/1442786862427475973">https://twitter.com/lcasillo/status/1442786862427475973</a></td>
#       <td id="T_3fc02_row7_col3" class="data row7 col3" >anger</td>
#     </tr>
#     <tr>
#       <th id="T_3fc02_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3fc02_row8_col0" class="data row8 col0" >il cmc alla 17 biennale di architettura di venezia, oggetti di design urbano e progetti riqualificazione quartiere #gratosoglio e #dergano ideati da studenti #accademiabrera
# giovani crescono, nuova cultura dell'abitare: vita memoria condivisione superano caduta qualita a milano https://t.co/diqqgxni3h</td>
#       <td id="T_3fc02_row8_col1" class="data row8 col1" >CmcMilano</td>
#       <td id="T_3fc02_row8_col2" class="data row8 col2" ><a href="https://twitter.com/CmcMilano/status/1441756596338520075">https://twitter.com/CmcMilano/status/1441756596338520075</a></td>
#       <td id="T_3fc02_row8_col3" class="data row8 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_3fc02_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3fc02_row9_col0" class="data row9 col0" >@piercamillo la sensazione a milano e questa, campagna elettorale complicatissima, tra design week e fashion week.</td>
#       <td id="T_3fc02_row9_col1" class="data row9 col1" >fzb</td>
#       <td id="T_3fc02_row9_col2" class="data row9 col2" ><a href="https://twitter.com/fzb/status/1440658880317378569">https://twitter.com/fzb/status/1440658880317378569</a></td>
#       <td id="T_3fc02_row9_col3" class="data row9 col3" >joy</td>
#     </tr>
#     <tr>
#       <th id="T_3fc02_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_3fc02_row10_col0" class="data row10 col0" >anche il design diventa bio: come l'edilizia puo diventare sostenibile - #bioedilizia #design #formazione #sostenibilita - tra le grandi protagoniste della milano design week appena trascorsa non sono mancate l'economia circolare e la sostenibilita https://t.co/axo98feykn</td>
#       <td id="T_3fc02_row10_col1" class="data row10 col1" >Green__Planner</td>
#       <td id="T_3fc02_row10_col2" class="data row10 col2" ><a href="https://twitter.com/Green__Planner/status/1438427589442424837">https://twitter.com/Green__Planner/status/1438427589442424837</a><

# %%
# Wordcloud

# %%
# Word frequency
# Out:
# [('design', 465), ('milano', 455), ('week', 226), ('2021', 79), ('settembre', 34), ('salone', 32), ('honda', 32), ('museo', 30), ('nuova', 28)]

# %%
# Out:
# Trigramma, sottosequenza di 3 elementi di una data sequenza e peso che hanno nei testi
# [('milano design week', 177),
#  ('alla milano design', 77),
#  ('design week 2021', 39),
#  ('design group tutta', 25),
#  ('group tutta convenzionalita', 25),
#  ('tutta convenzionalita alla', 25),
#  ('convenzionalita alla milano', 25),
#  ('milano museo design', 21),
#  ('della milano design', 20),
#  ('durante milano design', 15),
#  ('salone mobile milano', 15),
#  ('design week milano', 15),
#  ('honda full hybrid', 12),
#  ('marazzato alla milano', 11),
#  ('rifiuti ambiente successo', 10),
#  ('ambiente successo marazzato', 10),
#  ('successo marazzato alla', 10),
#  ('alla design week', 9),
#  ('giovedi venerdi settembre', 9),
#  ('fuori salone mobile', 9)]

# %%
# Out:
# per favore inserisci una parola o un hashtag: moda+milano
# Wall time: 7.78 s

# %%
# Out:
# Wall time: 34.7 s
